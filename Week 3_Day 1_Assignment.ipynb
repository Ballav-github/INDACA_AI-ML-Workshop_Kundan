# %% [markdown]
# ### 1. Create a 5X2 integer array and Print its attributes

# %%
import numpy as np
list = [22, 34, 56, 38, 67, 12, 87, 36, 73, 18]
arr = np.array(list, dtype = np.uint16)
arr = arr.reshape(5,2)
print(arr)
print(arr.shape)
print(arr.ndim)
print(arr.itemsize)
# Out:
# [[22 34]
#  [56 38]
#  [67 12]
#  [87 36]
#  [73 18]]
# (5, 2)
# 2
# 2

# %% [markdown]
# ### 2. Create an array by adding the following two NumPy arrays, Next, modify the result array by calculating the square of each elements

# %%
import numpy as np
arrayOne = np.array([[5, 6, 9], [21, 18, 27]])
arrayTwo = np.array([[15, 3, 24], [4, 7, 1]])
resultArray = arrayOne + arrayTwo
print("Addition of two arrays is: \n")
print(resultArray)
for num in np.nditer(resultArray, op_flags = ['readwrite']):
    num[...] = num*num
print("\nResult array by calculating the square of each elements: \n")
print(resultArray)
# Out:
# Addition of two arrays is:
#
# [[20  9 33]
#  [25 25 28]]
#
# Result array by calculating the square of each elements:
#
# [[ 400   81 1089]
#  [ 625  625  784]]

# %% [markdown]
# ### 3. Find the length of each string element in the NumPy array

# %%
import numpy as np
arr = np.array(['New Delhi', 'Moscow', 'New York', 'Bejing'])
print("The list of strings in array is:", arr)
length_checker = np.vectorize(len)
arr_len = length_checker(arr)
print("The length of each string element in the array is:", arr_len)
# Out:
# The list of strings in array is: ['New Delhi' 'Moscow' 'New York' 'Bejing']
# The length of each string element in the array is: [9 6 8 6]

# %% [markdown]
# ### 4. Find the mean, median and mode of a list of NumPy array

# %%
values = [99,86,87,88,111,86,103,87,94,78,77,85,86]
import numpy
x = numpy.mean(values)
print(x)
x = numpy.median(values)
print(x)
from scipy import stats
x = stats.mode(values)
print(x)
# Out:
# 89.76923076923077
# 87.0
# ModeResult(mode=86, count=3)

# %% [markdown]
# ### 5. Calculate the Elucidean distance using NumPy

# %%
import numpy as np
point1 = np.array((1, 2, 3))
point2 = np.array((1, 1, 1))
dist = np.linalg.norm(point1 - point2)
print("Elucidean distance is:", dist)
# Out:
# Elucidean distance is: 2.23606797749979

# %% [markdown]
# ### 6. COVID-19 Data Visualization using matplotlib in Python

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv('case_time_series (2).csv')

Y = data.iloc[61:,1].values 
R = data.iloc[61:,3].values 
D = data.iloc[61:,5].values 
X = data.iloc[61:,0] 

plt.figure(figsize=(25,8))

ax = plt.axes()
ax.grid(linewidth=0.4, color='#8f8f8f') 

ax.set_facecolor("black") 
ax.set_xlabel('\nDate',size=25,color='#4bb4f2')
ax.set_ylabel('Number of Confirmed Cases\n',
			size=25,color='#4bb4f2')

ax.plot(X,Y,
		color='#1F77B4',
		marker='o',
		linewidth=4,
		markersize=15,
		markeredgecolor='#035E9B')

# %% [markdown]
# ### 7. From the given Automobile_dataset print the first and last five rows

# %%
#First five Rows
import pandas as pd
df = pd.read_csv("C:\\Users\\Siraj\\INDACA_Week 3\\Automobile_data.csv")
df.head(5)
# Out:
#    index      company   body-style  wheel-base  length engine-type  \
# 0      0  alfa-romero  convertible        88.6   168.8        dohc
# 1      1  alfa-romero  convertible        88.6   168.8        dohc
# 2      2  alfa-romero    hatchback        94.5   171.2        ohcv
# 3      3         audi        sedan        99.8   176.6         ohc
# 4      4         audi        sedan        99.4   176.6         ohc
#
#   num-of-cylinders  horsepower  average-mileage    price
# 0             four         111               21  13495.0
# 1             four         111               21  16500.0
# 2              six         154               19  16500.0
# 3             four         102               24  13950.0
# 4             five         115               18  17450.0

# %%
#Last five Rows
import pandas as pd
df = pd.read_csv("C:\\Users\\Siraj\\INDACA_Week 3\\Automobile_data.csv")
df.tail(5)
# Out:
#     index     company body-style  wheel-base  length engine-type  \
# 56     81  volkswagen      sedan        97.3   171.7         ohc
# 57     82  volkswagen      sedan        97.3   171.7         ohc
# 58     86  volkswagen      sedan        97.3   171.7         ohc
# 59     87       volvo      sedan       104.3   188.8         ohc
# 60     88       volvo      wagon       104.3   188.8         ohc
#
#    num-of-cylinders  horsepower  average-mileage    price
# 56             four          85               27   7975.0
# 57             four          52               37   7995.0
# 58             four         100               26   9995.0
# 59             four         114               23  12940.0
# 60             four         114               23  13415.0

# %% [markdown]
# ### 8. Find the most expensive car company name

# %%
import pandas as pd
df = pd.read_csv("C:\\Users\\Siraj\\INDACA_Week 3\\Automobile_data.csv")
df = df [['company','price']][df.price==df['price'].max()]
df
# Out:
#           company    price
# 35  mercedes-benz  45400.0

# %% [markdown]
# ### 9. Count total cars per company

# %%
import pandas as pd
df = pd.read_csv("C:\\Users\\Siraj\\INDACA_Week 3\\Automobile_data.csv")
df['company'].value_counts()
# Out:
# company
# toyota           7
# bmw              6
# mazda            5
# nissan           5
# audi             4
# mercedes-benz    4
# mitsubishi       4
# volkswagen       4
# alfa-romero      3
# chevrolet        3
# honda            3
# isuzu            3
# jaguar           3
# porsche          3
# dodge            2
# volvo            2
# Name: count, dtype: int64

# %% [markdown]
# ### 10. Sort all cars per price column

# %%
import pandas as pd
carsDf = pd.read_csv("C:\\Users\\Siraj\\INDACA_Week 3\\Automobile_data.csv")
carsDf = carsDf.sort_values(by=['price', 'horsepower'], ascending=False)
carsDf.head(5)
# Out:
#     index        company   body-style  wheel-base  length engine-type  \
# 35     47  mercedes-benz      hardtop       112.0   199.2        ohcv
# 11     14            bmw        sedan       103.5   193.8         ohc
# 34     46  mercedes-benz        sedan       120.9   208.1        ohcv
# 46     62        porsche  convertible        89.5   168.9        ohcf
# 12     15            bmw        sedan       110.0   197.0         ohc
#
#    num-of-cylinders  horsepower  average-mileage    price
# 35            eight         184               14  45400.0
# 11              six         182               16  41315.0
# 34            eight         184               14  40960.0
# 46              six         207               17  37028.0
# 12              six         182               15  36880.0
